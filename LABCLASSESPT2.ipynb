# %% [markdown]
# <a href="https://colab.research.google.com/github/mlevy34/CLASSES-AND-OBJECTS-MICHELLE-LEVY/blob/main/LABCLASSESPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Pet:
  country = "USA"
  def __init__(self, name : str, age : int, owner : str)-> None:
    self.name = name
    self.age = age
    self.owner = owner
  # getters
  def get_name(self):
    return self.name
  def get_age(self):
    return self.age
  def get_owner(self):
    return self.owner
  # setters
  def set_name(self, new_name):
    self.name = new_name
  def set_age(self, age):
    self.age = age
  def set_owner(self, owner):
    self.owner = owner
pet1 = Pet("dog", 15, "John")
pet2 = Pet("cat", 4, "Sara")
print(pet1.get_name())
pet2.set_name("I dont know")
print(pet2.get_name())

Pet.country = "EU"
print(pet1.country)
print(pet2.country)
pet1.country = "ITALY"
print(pet1.country)
print(pet2.country)

Pet.country = "ISRAEL"
print(pet1.country)
# Out:
# dog
# I dont know
# EU
# EU
# ITALY
# EU
# ITALY

# %%
class Vet:
  def __init__(self, name : str, store : str, client : Pet)-> None:
    self.__name = name
    self.__store = store
    self.__client_name = client.get_owner()
    self.__pet_name = client.get_name()

  def get_client_name(self):
    return self.__client_name
  def get_petname(self):
    return self.__pet_name
  def __str__(self):
    return self.__client_name, self.__petsname

dr_raine = Vet("Aviva Goldner", "Ocean Avenue", pet1)
print(dr_raine.get_client_name())
print(dr_raine.get_petname())
# Out:
# John
# dog
