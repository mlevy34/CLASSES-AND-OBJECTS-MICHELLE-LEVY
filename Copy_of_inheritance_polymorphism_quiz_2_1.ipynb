# %% [markdown]
# <a href="https://colab.research.google.com/github/mlevy34/CLASSES-AND-OBJECTS-MICHELLE-LEVY/blob/main/Copy_of_inheritance_polymorphism_quiz_2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Quiz: Inheritance and Polymorphism in Python
#
# **Estimated time for a fast student:** about 30 minutes
#
# ## Directions
# Complete this quiz in the cells provided.
#
# ## Topics Covered
# - inheritance
# - parent and child classes
# - method overriding
# - polymorphism
# - identifying shared vs specialized behavior
#
# ## Rules
# - Write your own code.
# - Keep your work clear and readable.
# - Run all cells before submitting.

# %% [markdown]
# ## Question 1: Inheritance with Employees
#
# Create a parent class named `Employee`.
#
# ### `Employee` must:
# - store an employee name
# - store a department
# - include a method named `work()` that returns a general work message
#
# Then create a child class named `Manager`.
#
# ### `Manager` must:
# - inherit from `Employee`
# - use the parent constructor
# - override `work()` so that it returns a manager-specific message
#
# ### After writing your classes
# Create a `Manager` object and demonstrate that:
# - the object stores its data correctly
# - the overridden `work()` method is being used

# %%
# Write your answer for Question 1 here.
class Employee:
  def __init__(self, name : str, department : str)->None:
    self.name = name
    self.department = department

  def work(self)->str:
    return "work in progress"

class Manager(Employee):
  def __init__(self, name : str, department : str)->None:
    super().__init__(name, department)
  def work(self)->str:
    return "Manager is working"

manager_obj = Manager("Albert", "Car department")
print(manager_obj.name)
print(manager_obj.department)
print(manager_obj.work())
# Out:
# Albert
# Car department
# Manager is working

# %% [markdown]
# ## Question 2: Choose What Belongs in the Parent
#
# Below is a group of possible attributes and behaviors for electronic devices:
#
# - brand
# - battery_percent
# - charge()
# - take_photo()
# - make_call()
#
# Create a parent class named `Device` using only the information that should reasonably be shared by many devices.
#
# Then create a child class named `Phone`.
#
# ### Requirements
# - `Device` should store shared data and include at least one shared behavior
# - `Phone` should inherit from `Device`
# - `Phone` should add or override behavior that makes sense for a phone
#
# ### After writing your classes
# Create a `Phone` object and demonstrate that inherited behavior works correctly.

# %%
# Write your answer for Question 2 here.
class Device:
  def __init__(self, brand : str, battery_percent : int)->None:
    self.brand = brand
    self.battery_percent = battery_percent

  def charge(self)->str:
    return "device is charging"

  def take_photo(self)->str:
    return "click"

class Phone(Device):
  def __init__(self, brand : str, battery_percent : int)->None:
    super().__init__(brand, battery_percent)

  def charge(self):
    return "phone is charging"

  def make_call(self):
    return "calling..."

phone_obj = Phone("Apple", 98)
print(phone_obj.brand)
print(phone_obj.battery_percent)
print(phone_obj.charge())
print(phone_obj.take_photo())
print(phone_obj.make_call())
# Out:
# Apple
# 98
# phone is charging
# click
# calling...

# %% [markdown]
# ## Question 3: Polymorphism with School Roles
#
# Create a parent class named `SchoolMember` with a method named `introduce()`.
#
# Then create these child classes:
# - `Teacher`
# - `Student`
#
# Each child class should override `introduce()` in its own way.
#
# ### Then:
# 1. Create one `Teacher` object and one `Student` object
# 2. Store them together in a list
# 3. Use one loop to call `introduce()` on each object
#
# ## Goal
# Your output should clearly demonstrate polymorphism.

# %%
# Write your answer for Question 3 here.
class SchoolMember:
  def introduce(self)->str:
    return "This is a school member!"

class Teacher(SchoolMember):
  def introduce(self) -> str:
    return "This is a teacher!"

class Student(SchoolMember):
  def introduce(self) -> str:
    return "This is a student!"

teacher = Teacher()
student = Student()
lst = [teacher, student]
for item in lst:
  print(item.introduce())
# Out:
# This is a teacher!
# This is a student!

# %% [markdown]
# ## Question 4: Method Overriding Analysis
#
# Look at the code below.
#
# ```python
# class Appliance:
#     def start(self):
#         return "The appliance starts."
#
# class Blender(Appliance):
#     def start(self):
#         return "The blender spins."
# ```
#
# Answer both questions in complete sentences:
#
# 1. Why is `Blender` considered a child class?
# 2. What is different about calling `start()` on a `Blender` object versus an `Appliance` object?

# %% [markdown]
# 1. Blender is considered a child class since it inherits properties from
# the Appliance class, its parent.
# 2. What is different about caalling start() on a blender object and an appliance
# object is that since blender and appliance class both have a method named start, which is an example of polymorphism, the method of the child class overrides that of its parent whenever it is called. Therefore, when we call start() on specifically a blender object, the mthod being called is the one of the child while for a geeral Appliance object, the method of the appliance class is being called.

# %% [markdown]
# ## Question 5: Short Design Reflection
#
# Answer in complete sentences:
#
# Suppose you are creating these classes:
#
# - `Book`
# - `EBook`
# - `AudioBook`
#
# 1. What information or behavior would you place in the parent class?
# 2. Give one example of a method that a child class might override.

# %% [markdown]
# Write your answer for Question 5 here.
# 1. Some information and behavior I would place in the parent class is: Attributes: pages, title, author. A method I would put would be: read_book(),
# close_book(), these methods would return a string like "book is being read" or
# "book closed".
# 2. One example of a method a child class can override is the read_book() method. For instance, if the read_book() method is being called from the EBook class, the method might return "EBook is being read".

# %% [markdown]
# ## Bonus (Optional)
#
# Create your own small inheritance example with:
# - 1 parent class
# - 2 child classes
# - 1 overridden method
# - 1 loop that demonstrates polymorphism

# %%
# Write your bonus answer here.
class Food:
  def __init__(self, name : str, calories):
    self.name = name
    self.calories = calories

  def eat(self):
    return "Food is being eaten!"

class Candybar(Food):
  def __init__(self, name, calories):
    super().__init__(name, calories)

  def eat(self):
    return "Candy bar is being eaten!"

class Vegtable(Food):
  def __init__(self, name, calories):
    super().__init__(name, calories)

  def eat(self):
    return "Vegtable is being eaten!"
candybar = Candybar("airhead", 190)
vegtable = Vegtable("carrot", 20)
lst = [candybar, vegtable]
for item in lst:
  print(item.eat())
# Out:
# Candy bar is being eaten!
# Vegtable is being eaten!

# %% [markdown]
# ## Submission Checklist
#
# Before submitting, make sure:
# - your child classes inherit correctly
# - your overridden methods behave differently from the parent version
# - your polymorphism example uses a list and a loop
# - your notebook runs without errors
